# %%
## if statement
age = int(input("Enter your age: "))
if age >= 18:
    print("You are an adult.")
else:
    print("You are a minor.")
# Out:
# You are an adult.

# %%
## elif statement
if age < 13:
    print("You are a child.")
elif age < 18:
    print("You are a teenager.")
elif age == 18:
    print("Congratulations on becoming an adult!")
elif age >= 30:
    print("You are an adult.") 
else:
    print("Hey you are something unexplainable.")
# Out:
# Hey you are something unexplainable.

# %%
## Nested Conditional Statements.
if age >= 18:
    if age < 30:
        print("You are a young adult.")
    else:
        print("You are an adult.")
# Out:
# You are a young adult.

# %%
## Practical Implication of Conditional Statements.
year = int(input("Enter the year: "))
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print(f"{year} is a leap year.")
        else:
            print(f"{year} is not a leap year.")
    else:
        print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 1900 is not a leap year.

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
Operation = input("Enter the operation (+, -, *, /): ")
if(Operation == '+'):
    result = num1 + num2
    print(f"The result of {num1} + {num2} is: {result}")
elif(Operation == '-'):
    result = num1 - num2
    print(f"The result of {num1} - {num2} is: {result}")
elif(Operation == '*'):
    result = num1 * num2
    print(f"The result of {num1} * {num2} is: {result}")
elif(Operation == '/'):
    result = num1 / num2
    print(f"The result of {num1} / {num2} is: {result}")
# Out:
# The result of 16.0 - -6.0 is: 22.0

# %%
age = int(input("Enter your age: "))
is_student = input("Are you a student? (yes/no): ").lower()
if is_student == "no":
    price = "$100"
else:
    if age <= 18:
        price = "$50"
    elif age < 25:
        price = "$75"
    elif age <=10:
        price = "Free"
    elif age >= 80:
        price = "Free"
    else:
        price = "$100"
print(f"The ticket price is: {price}")
# Out:
# The ticket price is: $100
