# %%
## Integers
a = 10
type(a)
# Out:
# int

# %%
## floating point datatype
height = 1.75
print(height)
print(type(height))
# Out:
# 1.75
# <class 'float'>

# %%
## string Datatype
name = "John Doe"
print(name)
print(type(name))
# Out:
# John Doe
# <class 'str'>

# %%
## boolean Datatype
is_student = True
print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>

# %%
a = 10 
b = 10
type(a==b)
# Out:
# bool

# %%
## common errors
result = "Hello" + '5'
print(result)
# Out:
# Hello5
