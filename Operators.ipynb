# %%
## Arithmethic Operations
from unittest import result


a = 15
b = 10 
add_result = a + b
sub_result = a - b
mult_result = a * b
div_result = a / b
floor_div_result = a // b
modulus_result = a % b
exponent_result = a ** b
print("The sum of a and b is: ", add_result) 
print("The difference of a and b is: ", sub_result)
print("The product of a and b is: ", mult_result)
print("The quotient of a and b is: ", div_result)
print("The floor division of a and b is: ", floor_div_result)
print("The modulus of a and b is: ", modulus_result)
print("The exponent of a and b is: ", exponent_result)
# Out:
# The sum of a and b is:  25
# The difference of a and b is:  5
# The product of a and b is:  150
# The quotient of a and b is:  1.5
# The floor division of a and b is:  1
# The modulus of a and b is:  5
# The exponent of a and b is:  576650390625

# %%
## Comparison Operators
x = 5
y = 5
x==y
# Out:
# True

# %%
str1 = "Hello"
str2 = "Hello"
str1 == str2
# Out:
# True

# %%
str1 != str2
# Out:
# False

# %%
# greater than
num1 = 45 
num2 = 30
print("Num1 is greater than Num2:", num1 > num2)
# less than
print("Num1 is less than Num2:", num1 < num2)
# Out:
# Num1 is greater than Num2: True
# Num1 is less than Num2: False

# %%
# Greater than or equal to
number1 = 20
number2 = 20
number1 >= number2
print("Number1 is greater than or equal to Number2:", number1 >= number2)
# Less than or equal to
print("Number1 is less than or equal to Number2:", number1 <= number2)
# Out:
# Number1 is greater than or equal to Number2: True
# Number1 is less than or equal to Number2: True

# %% [markdown]
# Logical Operators

# %%
## And, Not, OR operators
X = True
Y = True
result = X and Y
print("The result of X and Y is: ", result)
# Out:
# The result of X and Y is:  True

# %%
## OR operator
X = False
Y = False
result = X or Y
print("The result of X or Y is: ", result)
# Out:
# The result of X or Y is:  False

# %%
## Not Operator
X = True
result = not X
print("The result of not X is: ", result)
# Out:
# The result of not X is:  False
